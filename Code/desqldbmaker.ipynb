# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
#df = pd.read_csv("housing.csv")

# %%
#df

# %%
"""import pandas as pd
from geopy.geocoders import Nominatim
from geopy.point import Point

# Initialize Nominatim API
geolocator = Nominatim(user_agent="test")

def reverse_geocoding(lat, lon):
    try:
        location = geolocator.reverse(Point(lat, lon))
        print(location)
        return location.raw['display_name']
    except:
        return None


# Apply reverse geocoding
df['address'] = np.vectorize(reverse_geocoding)(df['latitude'], df['longitude'])

print(df)"""
# Out:
# 'import pandas as pd\nfrom geopy.geocoders import Nominatim\nfrom geopy.point import Point\n\n# Initialize Nominatim API\ngeolocator = Nominatim(user_agent="test")\n\ndef reverse_geocoding(lat, lon):\n    try:\n        location = geolocator.reverse(Point(lat, lon))\n        print(location)\n        return location.raw[\'display_name\']\n    except:\n        return None\n\n\n# Apply reverse geocoding\ndf[\'address\'] = np.vectorize(reverse_geocoding)(df[\'latitude\'], df[\'longitude\'])\n\nprint(df)'

# %%
#df.to_csv("new.csv")

# %%
import sqlalchemy as sql

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///db1.db')

# %%
df = pd.read_csv('property_crime_data.csv')
df.to_sql(name='crime_table', con=engine, if_exists='replace')
# Out:
# 460

# %%
housedf = pd.read_csv('new.csv')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0          city population robbery_crime  \
# 0               0           0      Adelanto     33,005            48
# 1               1           1  Agoura Hills     20,970             6
# 2               2           2       Alameda     78,613            61
# 3               3           3        Albany     19,723            16
# 4               4           4      Alhambra     86,175            74
# ..            ...         ...           ...        ...           ...
# 455           455         455    Yountville      3,030             0
# 456           456         456         Yreka      7,507             4
# 457           457         457     Yuba City     65,974            66
# 458           458         458       Yucaipa     53,498            22
# 459           459         459  Yucca Valley     21,672            30
#
#     property_crime burglary_crime larceny_theft motor_vehicle_theft arson  \
# 0              808            434           254                 120    24
# 1              310             82           217                  11     0
# 2            1,819            228         1,245                 346    18
# 3              605             95           447                  63     0
# 4            1,929            305         1,413                 211     6
# ..             ...            ...           ...                 ...   ...
# 455             46              7            36                   3     0
# 456            309             85           188                  36     1
# 457          1,792            429         1,160                 203    14
# 458          1,309            263           838                 208    12
# 459            664            217           381                  66     8
#
#      average_housing_age  total_rooms  total_bedrooms  population_drop  \
# 0              10.666667       9268.0          2240.0           5614.0
# 1               8.000000      33408.0          4597.0          14016.0
# 2              45.057692     131786.0         25494.0          63137.0
# 3              42.750000      32001.0          7151.0          14683.0
# 4              37.437500     117422.0         28248.0          81333.0
# ..                   ...          ...             ...              ...
# 455            17.000000       4524.0           946.0           1866.0
# 456            29.800000      15337.0          3154.0           6913.0
# 457            23.933333      75544.0         15072.0          38624.0
# 458            24.421053      67846.0         13307.0          30949.0
# 459            14.285714      32324.0          6418.0          13857.0
#
#      total_households  average_income  average_house_value
# 0              2004.0        1.681733         66933.333333
# 1              4397.0        6.934250        449600.500000
# 2             25795.0        3.813152        247886.538462
# 3              6810.0        3.669300        220562.500000
# 4             27308.0        3.206000        217750.000000
# ..                ...             ...                  ...
# 455             870.0        2.980150        188100.000000
# 456            3011.0        2.262380         65780.000000
# 457           14441.0        2.884130         92993.333333
# 458           12464.0        3.034968        124742.105263
# 459            5763.0        2.718271         88557.142857
#
# [460 rows x 17 columns]

# %%
housedf
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               0    -122.23     37.88                41.0        880.0
# 1               1    -122.22     37.86                21.0       7099.0
# 2               2    -122.24     37.85                52.0       1467.0
# 3               3    -122.25     37.85                52.0       1274.0
# 4               4    -122.25     37.85                52.0       1627.0
# ...           ...        ...       ...                 ...          ...
# 20635       20635    -121.09     39.48                25.0       1665.0
# 20636       20636    -121.21     39.49                18.0        697.0
# 20637       20637    -121.22     39.43                17.0       2254.0
# 20638       20638    -121.32     39.43                18.0       1860.0
# 20639       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# 1              1106.0      2401.0      1138.0         8.3014
# 2               190.0       496.0       177.0         7.2574
# 3               235.0       558.0       219.0         5.6431
# 4               280.0       565.0       259.0         3.8462
# ...               ...         ...         ...            ...
# 20635           374.0       845.0       330.0         1.5603
# 20636           150.0       356.0       114.0         2.5568
# 20637           485.0      1007.0       433.0         1.7000
# 20638           409.0       741.0       349.0         1.8672
# 20639           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity  \
# 0                452600.0        NEAR BAY
# 1                358500.0        NEAR BAY
# 2                352100.0        NEAR BAY
# 3                341300.0        NEAR BAY
# 4                342200.0        NEAR BAY
# ...                   ...             ...
# 20635             78100.0          INLAND
# 20636             77100.0          INLAND
# 20637             92300.0          INLAND
# 20638             84700.0          INLAND
# 20639             89400.0          INLAND
#
#                                                  address
# 0      Ecological Study Area, Smyth Road, Panoramic H...
# 1      Grizzly Peak Open Space, Fish Ranch Road, Oakl...
# 2      Grove Shafter Freeway, Upper Rockridge, Oaklan...
# 3      6365, Florio Street, Rockridge, Oakland, Alame...
# 4      6365, Florio Street, Rockridge, Oakland, Alame...
# ...                                                  ...
# 20635  Garden Valley Road, Yuba County, California, 9...
# 20636  La Porte Road, Woodleaf, Challenge, Yuba Count...
# 20637  Indiana Ranch Road, Yuba County, California, 9...
# 20638  Vierra Road, Yuba County, California, 95972, U...
# 20639  9429, Marysville Road, Yuba County, California...
#
# [20640 rows x 12 columns]

# %%
housedf['city'] = ""

# %%
housedf
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               0    -122.23     37.88                41.0        880.0
# 1               1    -122.22     37.86                21.0       7099.0
# 2               2    -122.24     37.85                52.0       1467.0
# 3               3    -122.25     37.85                52.0       1274.0
# 4               4    -122.25     37.85                52.0       1627.0
# ...           ...        ...       ...                 ...          ...
# 20635       20635    -121.09     39.48                25.0       1665.0
# 20636       20636    -121.21     39.49                18.0        697.0
# 20637       20637    -121.22     39.43                17.0       2254.0
# 20638       20638    -121.32     39.43                18.0       1860.0
# 20639       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# 1              1106.0      2401.0      1138.0         8.3014
# 2               190.0       496.0       177.0         7.2574
# 3               235.0       558.0       219.0         5.6431
# 4               280.0       565.0       259.0         3.8462
# ...               ...         ...         ...            ...
# 20635           374.0       845.0       330.0         1.5603
# 20636           150.0       356.0       114.0         2.5568
# 20637           485.0      1007.0       433.0         1.7000
# 20638           409.0       741.0       349.0         1.8672
# 20639           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity  \
# 0                452600.0        NEAR BAY
# 1                358500.0        NEAR BAY
# 2                352100.0        NEAR BAY
# 3                341300.0        NEAR BAY
# 4                342200.0        NEAR BAY
# ...                   ...             ...
# 20635             78100.0          INLAND
# 20636             77100.0          INLAND
# 20637             92300.0          INLAND
# 20638             84700.0          INLAND
# 20639             89400.0          INLAND
#
#                                                  address city
# 0      Ecological Study Area, Smyth Road, Panoramic H...
# 1      Grizzly Peak Open Space, Fish Ranch Road, Oakl...
# 2      Grove Shafter Freeway, Upper Rockridge, Oaklan...
# 3      6365, Florio Street, Rockridge, Oakland, Alame...
# 4      6365, Florio Street, Rockridge, Oakland, Alame...
# ...                                                  ...  ...
# 20635  Garden Valley Road, Yuba County, California, 9...
# 20636  La Porte Road, Woodleaf, Challenge, Yuba Count...
# 20637  Indiana Ranch Road, Yuba County, California, 9...
# 20638  Vierra Road, Yuba County, California, 95972, U...
# 20639  9429, Marysville Road, Yuba County, California...
#
# [20640 rows x 13 columns]

# %%
housedf['city'] = ''
cities = df['city'].tolist()

# define a lambda function to extract the city and match it with the list of cities
match_city = lambda x: [city for city in cities if city in x]

# apply the lambda function to the 'address' column
housedf['city'] = housedf['address'].apply(match_city)

# print the resulting dataframe
print(housedf)
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               0    -122.23     37.88                41.0        880.0
# 1               1    -122.22     37.86                21.0       7099.0
# 2               2    -122.24     37.85                52.0       1467.0
# 3               3    -122.25     37.85                52.0       1274.0
# 4               4    -122.25     37.85                52.0       1627.0
# ...           ...        ...       ...                 ...          ...
# 20635       20635    -121.09     39.48                25.0       1665.0
# 20636       20636    -121.21     39.49                18.0        697.0
# 20637       20637    -121.22     39.43                17.0       2254.0
# 20638       20638    -121.32     39.43                18.0       1860.0
# 20639       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# 1              1106.0      2401.0      1138.0         8.3014
# 2               190.0       496.0       177.0         7.2574
# 3               235.0       558.0       219.0         5.6431
# 4               280.0       565.0       259.0         3.8462
# ...               ...         ...         ...            ...
# 20635           374.0       845.0       330.0         1.5603
# 20636           150.0       356.0       114.0         2.5568
# 20637           485.0      1007.0       433.0         1.7000
# 20638           409.0       741.0       349.0         1.8672
# 20639           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity  \
# 0                452600.0        NEAR BAY
# 1                358500.0        NEAR BAY
# 2                352100.0        NEAR BAY
# 3                341300.0        NEAR BAY
# 4                342200.0        NEAR BAY
# ...                   ...             ...
# 20635             78100.0          INLAND
# 20636             77100.0          INLAND
# 20637             92300.0          INLAND
# 20638             84700.0          INLAND
# 20639             89400.0          INLAND
#
#                                                  address  \
# 0      Ecological Study Area, Smyth Road, Panoramic H...
# 1      Grizzly Peak Open Space, Fish Ranch Road, Oakl...
# 2      Grove Shafter Freeway, Upper Rockridge, Oaklan...
# 3      6365, Florio Street, Rockridge, Oakland, Alame...
# 4      6365, Florio Street, Rockridge, Oakland, Alame...
# ...                                                  ...
# 20635  Garden Valley Road, Yuba County, California, 9...
# 20636  La Porte Road, Woodleaf, Challenge, Yuba Count...
# 20637  Indiana Ranch Road, Yuba County, California, 9...
# 20638  Vierra Road, Yuba County, California, 95972, U...
# 20639  9429, Marysville Road, Yuba County, California...
#
#                               city
# 0              [Alameda, Berkeley]
# 1               [Alameda, Oakland]
# 2      [Alameda, Oakland, Shafter]
# 3               [Alameda, Oakland]
# 4               [Alameda, Oakland]
# ...                            ...
# 20635                           []
# 20636                           []
# 20637                           []
# 20638                           []
# 20639                 [Marysville]
#
# [20640 rows x 13 columns]

# %%
housedf
# Out:
#        Unnamed: 0  longitude  latitude  housing_median_age  total_rooms  \
# 0               0    -122.23     37.88                41.0        880.0
# 1               1    -122.22     37.86                21.0       7099.0
# 2               2    -122.24     37.85                52.0       1467.0
# 3               3    -122.25     37.85                52.0       1274.0
# 4               4    -122.25     37.85                52.0       1627.0
# ...           ...        ...       ...                 ...          ...
# 20635       20635    -121.09     39.48                25.0       1665.0
# 20636       20636    -121.21     39.49                18.0        697.0
# 20637       20637    -121.22     39.43                17.0       2254.0
# 20638       20638    -121.32     39.43                18.0       1860.0
# 20639       20639    -121.24     39.37                16.0       2785.0
#
#        total_bedrooms  population  households  median_income  \
# 0               129.0       322.0       126.0         8.3252
# 1              1106.0      2401.0      1138.0         8.3014
# 2               190.0       496.0       177.0         7.2574
# 3               235.0       558.0       219.0         5.6431
# 4               280.0       565.0       259.0         3.8462
# ...               ...         ...         ...            ...
# 20635           374.0       845.0       330.0         1.5603
# 20636           150.0       356.0       114.0         2.5568
# 20637           485.0      1007.0       433.0         1.7000
# 20638           409.0       741.0       349.0         1.8672
# 20639           616.0      1387.0       530.0         2.3886
#
#        median_house_value ocean_proximity  \
# 0                452600.0        NEAR BAY
# 1                358500.0        NEAR BAY
# 2                352100.0        NEAR BAY
# 3                341300.0        NEAR BAY
# 4                342200.0        NEAR BAY
# ...                   ...             ...
# 20635             78100.0          INLAND
# 20636             77100.0          INLAND
# 20637             92300.0          INLAND
# 20638             84700.0          INLAND
# 20639             89400.0          INLAND
#
#                                                  address        city
# 0      Ecological Study Area, Smyth Road, Panoramic H...     Alameda
# 1      Grizzly Peak Open Space, Fish Ranch Road, Oakl...     Alameda
# 2      Grove Shafter Freeway, Upper Rockridge, Oaklan...     Alameda
# 3      6365, Florio Street, Rockridge, Oakland, Alame...     Alameda
# 4      6365, Florio Street, Rockridge, Oakland, Alame...     Alameda
# ...                                                  ...         ...
# 20635  Garden Valley Road, Yuba County, California, 9...        None
# 20636  La Porte Road, Woodleaf, Challenge, Yuba Count...        None
# 20637  Indiana Ranch Road, Yuba County, California, 9...        None
# 20638  Vierra Road, Yuba County, California, 95972, U...        None
# 20639  9429, Marysville Road, Yuba County, California...  Marysville
#
# [20640 rows x 13 columns]

# %%
housedf.to_csv('housingwcities.csv')

# %%
#reprrocessing
# extract the second element of the column
housedf['guessed_city'] = df['city'].str.split(",").str[1]

# %%
housedf.to_sql(name='property_table_one', con=engine, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:918, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     917 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 918     cursor.executemany(statement, parameters)
#
# ProgrammingError: Error binding parameter 14: type 'list' is not supported
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /Users/aaronl/Documents/DEproject/deproject.ipynb Cell 19 line 1
# ----> <a href='vscode-notebook-cell:/Users/aaronl/Documents/DEproject/deproject.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> housedf.to_sql(name='property_table_one', con=engine, if_exists='replace')
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/core/generic.py:3008, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2813 """
#    2814 Write records stored in a DataFrame to a SQL database.
#    2815
#    (...)
#    3004 [(1,), (None,), (2,)]
#    3005 """  # noqa: E501
#    3006 from pandas.io import sql
# -> 3008 return sql.to_sql(
#    3009     self,
#    3010     name,
#    3011     con,
#    3012     schema=schema,
#    3013     if_exists=if_exists,
#    3014     index=index,
#    3015     index_label=index_label,
#    3016     chunksize=chunksize,
#    3017     dtype=dtype,
#    3018     method=method,
#    3019 )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:788, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     783     raise NotImplementedError(
#     784         "'frame' argument should be either a Series or a DataFrame"
#     785     )
#     787 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 788     return pandas_sql.to_sql(
#     789         frame,
#     790         name,
#     791         if_exists=if_exists,
#     792         index=index,
#     793         index_label=index_label,
#     794         schema=schema,
#     795         chunksize=chunksize,
#     796         dtype=dtype,
#     797         method=method,
#     798         engine=engine,
#     799         **engine_kwargs,
#     800     )
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:1958, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1946 sql_engine = get_engine(engine)
#    1948 table = self.prep_table(
#    1949     frame=frame,
#    1950     name=name,
#    (...)
#    1955     dtype=dtype,
#    1956 )
# -> 1958 total_inserted = sql_engine.insert_records(
#    1959     table=table,
#    1960     con=self.con,
#    1961     frame=frame,
#    1962     name=name,
#    1963     index=index,
#    1964     schema=schema,
#    1965     chunksize=chunksize,
#    1966     method=method,
#    1967     **engine_kwargs,
#    1968 )
#    1970 self.check_case_sensitive(name=name, schema=schema)
#    1971 return total_inserted
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:1507, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1505 if re.search(msg, err_text):
#    1506     raise ValueError("inf cannot be used with MySQL") from err
# -> 1507 raise err
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:1498, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1495 from sqlalchemy import exc
#    1497 try:
# -> 1498     return table.insert(chunksize=chunksize, method=method)
#    1499 except exc.StatementError as err:
#    1500     # GH34431
#    1501     # https://stackoverflow.com/a/67358288/6067848
#    1502     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1503     )|inf can not be used with MySQL"""
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:1059, in SQLTable.insert(self, chunksize, method)
#    1056     break
#    1058 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1059 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1060 # GH 46891
#    1061 if num_inserted is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/pandas/io/sql.py:951, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     939 """
#     940 Execute SQL statement inserting data
#     941
#    (...)
#     948    Each item contains a list of values to be inserted
#     949 """
#     950 data = [dict(zip(keys, row)) for row in data_iter]
# --> 951 result = conn.execute(self.table.insert(), data)
#     952 return result.rowcount
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/sql/elements.py:516, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     514     if TYPE_CHECKING:
#     515         assert isinstance(self, Executable)
# --> 516     return connection._execute_clauseelement(
#     517         self, distilled_params, execution_options
#     518     )
#     519 else:
#     520     raise exc.ObjectNotExecutableError(self)
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1635, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1623 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1624     "compiled_cache", self.engine._compiled_cache
#    1625 )
#    1627 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1628     dialect=dialect,
#    1629     compiled_cache=compiled_cache,
#    (...)
#    1633     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1634 )
# -> 1635 ret = self._execute_context(
#    1636     dialect,
#    1637     dialect.execution_ctx_cls._init_compiled,
#    1638     compiled_sql,
#    1639     distilled_parameters,
#    1640     execution_options,
#    1641     compiled_sql,
#    1642     distilled_parameters,
#    1643     elem,
#    1644     extracted_params,
#    1645     cache_hit=cache_hit,
#    1646 )
#    1647 if has_events:
#    1648     self.dispatch.after_execute(
#    1649         self,
#    1650         elem,
#    (...)
#    1654         ret,
#    1655     )
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1934, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1932                 break
#    1933     if not evt_handled:
# -> 1934         self.dialect.do_executemany(
#    1935             cursor,
#    1936             str_statement,
#    1937             effective_parameters,
#    1938             context,
#    1939         )
#    1940 elif not effective_parameters and context.no_parameters:
#    1941     if self.dialect._has_events:
#
# File ~/miniconda3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:918, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     917 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 918     cursor.executemany(statement, parameters)
#
# ProgrammingError: (sqlite3.ProgrammingError) Error binding parameter 14: type 'list' is not supported
# [SQL: INSERT INTO property_table_one ("index", "Unnamed: 0", longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity, address, city, guessed_city) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: [(0, 0, -122.23, 37.88, 41.0, 880.0, 129.0, 322.0, 126.0, 8.3252, 452600.0, 'NEAR BAY', 'Ecological Study Area, Smyth Road, Panoramic Hill, Berkeley, Alameda County, California, 94720, United States', ['Alameda', 'Berkeley'], None), (1, 1, -122.22, 37.86, 21.0, 7099.0, 1106.0, 2401.0, 1138.0, 8.3014, 358500.0, 'NEAR BAY', 'Grizzly Peak Open Space, Fish Ranch Road, Oakland, Alameda County, California, 94563, United States', ['Alameda', 'Oakland'], None), (2, 2, -122.24, 37.85, 52.0, 1467.0, 190.0, 496.0, 177.0, 7.2574, 352100.0, 'NEAR BAY', 'Grove Shafter Freeway, Upper Rockridge, Oakland, Alameda County, California, 94618, United States', ['Alameda', 'Oakland', 'Shafter'], None), (3, 3, -122.25, 37.85, 52.0, 1274.0, 235.0, 558.0, 219.0, 5.6431, 341300.0, 'NEAR BAY', '6365, Florio Street, Rockridge, Oakland, Alameda County, California, 94168, United States', ['Alameda', 'Oakland'], None), (4, 4, -122.25, 37.85, 52.0, 1627.0, 280.0, 565.0, 259.0, 3.8462, 342200.0, 'NEAR BAY', '6365, Florio Street, Rockridge, Oakland, Alameda County, California, 94168, United States', ['Alameda', 'Oakland'], None), (5, 5, -122.25, 37.85, 52.0, 919.0, 213.0, 413.0, 193.0, 4.0368, 269700.0, 'NEAR BAY', '6365, Florio Street, Rockridge, Oakland, Alameda County, California, 94168, United States', ['Alameda', 'Oakland'], None), (6, 6, -122.25, 37.84, 52.0, 2535.0, 489.0, 1094.0, 514.0, 3.6591, 299200.0, 'NEAR BAY', '5401, Bryant Avenue, Rockridge, North Oakland, Oakland, Alameda County, California, 94168, United States', ['Alameda', 'Oakland'], None), (7, 7, -122.25, 37.84, 52.0, 3104.0, 687.0, 1157.0, 647.0, 3.12, 241400.0, 'NEAR BAY', '5401, Bryant Avenue, Rockridge, North Oakland, Oakland, Alameda County, California, 94168, United States', ['Alameda', 'Oakland'], None)  ... displaying 10 of 20640 total bound parameter sets ...  (20638, 20638, -121.32, 39.43, 18.0, 1860.0, 409.0, 741.0, 349.0, 1.8672, 84700.0, 'INLAND', 'Vierra Road, Yuba County, California, 95972, United States', [], None), (20639, 20639, -121.24, 39.37, 16.0, 2785.0, 616.0, 1387.0, 530.0, 2.3886, 89400.0, 'INLAND', '9429, Marysville Road, Yuba County, California, 95962, United States', ['Marysville'], None)]]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
len(housedf)
# Out:
# 20640
